# %%
import requests
import time
import pandas as pd
import json
from datetime import datetime, timedelta

API_KEY_ALPHA = "L6R9P7UB4N6X2ZCE"

symbols_array = symbols.split(",")

for symbol in symbols_array:
    url = f"https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol={symbol}&interval=5min&outputsize=full&apikey={API_KEY_ALPHA}"
    file_path = f"/lakehouse/default/Files/{symbol}_history_data.json"

    response = requests.get(url)

    if response.status_code == 200:
        data_hist = response.json()

        with open(file_path, "a") as json_file:
            json.dump(data_hist, json_file, indent=4)

    else:
        print(f"Fehler bei {symbol}: HTTP {response.status_code}")
# Out:
# StatementMeta(, b8ae70d7-e4a0-4398-b280-84c67269b96f, 4, Finished, Available, Finished)

# %%
df = spark.read.option("multiline", "true").json("Files/QQQ_history_data.json")
# df now is a Spark DataFrame containing JSON data from "Files/QQQ_history_data.json".
display(df)
# Out:
# StatementMeta(, b8ae70d7-e4a0-4398-b280-84c67269b96f, 5, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, c8c7998b-76c8-4c73-a96b-3814862b2c62)
